# %%
#!/usr/bin/env python
# -*- coding: utf-8 -*-
# Columbia EECS E6893 Big Data Analytics
"""
This module is the spark streaming analysis process.


Usage:
    If used with dataproc:
        gcloud dataproc jobs submit pyspark --cluster <Cluster Name> twitterHTTPClient.py

    Create a dataset in BigQurey first using
        bq mk bigdata_sparkStreaming

    Remeber to replace the bucket with your own bucket name


Todo:
    1. hashtagCount: calculate accumulated hashtags count
    2. wordCount: calculate word count every 60 seconds
        the word you should track is listed below.
    3. save the result to google BigQuery

"""

from pyspark import SparkConf,SparkContext
from pyspark.streaming import StreamingContext
from pyspark.sql import Row,SQLContext
import sys
import requests
import time
import subprocess
import re
from google.cloud import bigquery

# global variables
bucket = "twitterzzx"    # TODO : replace with your own bucket name
#hadoop/tmp/bigquery/pyspark_output/
#hadoop/tmp/bigquery/pyspark_output/
output_directory_hashtags = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/hashtagsCount'.format(bucket)
output_directory_wordcount = 'gs://{}/hadoop/tmp/bigquery/pyspark_output/wordcount'.format(bucket)

# output table and columns name
output_dataset = 'twitter'                     #the name of your dataset in BigQuery
output_table_hashtags = 'hashtags'
columns_name_hashtags = ['hashtags', 'count']
output_table_wordcount = 'wordcount'
columns_name_wordcount = ['word', 'count', 'time']

# parameter
IP = 'localhost'    # ip port
PORT = 9001       # port

STREAMTIME =120          # time that the streaming process runs

WORD = ['data', 'spark', 'ai', 'movie', 'good']     #the words you should filter and do word count

def updateFunction(newValues, runningCount):
    if runningCount is None:
        runningCount = 0
    return sum(newValues, runningCount)

# Helper functions
def saveToStorage(rdd, output_directory, columns_name, mode):
    """
    Save each RDD in this DStream to google storage
    Args:
        rdd: input rdd
        output_directory: output directory in google storage
        columns_name: columns name of dataframe
        mode: mode = "overwirte", overwirte the file
              mode = "append", append data to the end of file
    """
    if not rdd.isEmpty():
        (rdd.toDF( columns_name ) \
        .write.save(output_directory, format="json", mode=mode))


def saveToBigQuery(sc, output_dataset, output_table, directory):
    """
    Put temp streaming json files in google storage to google BigQuery
    and clean the output files in google storage
    """
    files = directory + '/part-*'
    subprocess.check_call(
        'bq load --source_format NEWLINE_DELIMITED_JSON '
        '--replace '
        '--autodetect '
        '{dataset}.{table} {files}'.format(
            dataset=output_dataset, table=output_table, files=files
        ).split())
    output_path = sc._jvm.org.apache.hadoop.fs.Path(directory)
    output_path.getFileSystem(sc._jsc.hadoopConfiguration()).delete(
        output_path, True)


def hashtagCount(words):
    """
    Calculate the accumulated hashtags count sum from the beginning of the stream
    and sort it by descending order of the count.
    Ignore case sensitivity when counting the hashtags:
        "#Ab" and "#ab" is considered to be a same hashtag
    You have to:
    1. Filter out the word that is hashtags.
       Hashtag usually start with "#" and followed by a serious of alphanumeric
    2. map (hashtag) to (hashtag, 1)
    3. sum the count of current DStream state and previous state
    4. transform unordered DStream to a ordered Dstream
    Hints:
        you may use regular expression to filter the words
        You can take a look at updateStateByKey and transform transformations
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (hashtag, count)
    """
    tag_filter = words.filter(lambda x:(x != "")and(x[0]=="#")and re.match("[A-Za-z0-9]+$",x[1:]) is not None).map(lambda x:(x.lower(),1)).updateStateByKey(updateFunction)
    res = tag_filter.transform(lambda rdd:rdd.sortBy(lambda x:x[1],False))
    return res

    # TODO: insert your code here
    pass

def wordCount(words):
    """
    Calculte the count of 5 sepcial words for every 60 seconds (window no overlap)
    You can choose your own words.
    Your should:
    1. filter the words
    2. count the word during a special window size
    3. add a time related mark to the output of each window, ex: a datetime type
    Hints:
        You can take a look at reduceByKeyAndWindow transformation
        Dstream is a serious of rdd, each RDD in a DStream contains data from a certain interval
        You may want to take a look of transform transformation of DStream when trying to add a time
    Args:
        dstream(DStream): stream of real time tweets
    Returns:
        DStream Object with inner structure (word, (count, time))
    """
    word_zzx = ["I","ai","check","you","are"]
    words_filter = words.filter(lambda x:x in word_zzx).map(lambda x:(x,1))
    words_count = words_filter.reduceByKeyAndWindow(lambda x, y: x + y, lambda x, y: x - y, 60, 60)
    res = words_count.transform(lambda rdd:rdd.sortBy(lambda x:x[1],False))
    
    return res

    # TODO: insert your code here
    pass


if __name__ == '__main__':
    # Spark settings
    conf = SparkConf()
    conf.setMaster('local[2]')
    conf.setAppName("TwitterStreamApp")

    # create spark context with the above configuration
    #sc = SparkContext(conf=conf)
    sc.setLogLevel("ERROR")

    # create sql context, used for saving rdd
    sql_context = SQLContext(sc)

    # create the Streaming Context from the above spark context with batch interval size 5 seconds
    ssc = StreamingContext(sc, 5)
    # setting a checkpoint to allow RDD recovery
    ssc.checkpoint("~/checkpoint_TwitterApp")

    # read data from port 9001
    dataStream = ssc.socketTextStream(IP, PORT)
    #dataStream.pprint()
    
    
    words = dataStream.flatMap(lambda line: line.split(" "))

    # calculate the accumulated hashtags count sum from the beginning of the stream
    topTags = hashtagCount(words)
    topTags.pprint()

    # Calculte the word count during each time period 6s
    wordCount = wordCount(words)
    wordCount.pprint()
    
    # save hashtags count and word count to google storage
    # used to save to google BigQuery
    # You should:
    #   1. topTags: only save the lastest rdd in DStream
    #   2. wordCount: save each rdd in DStream
    # Hints:
    #   1. You can take a look at foreachRDD transformation
    #   2. You may want to use helper function saveToStorage
    #   3. You should use save output to output_directory_hashtags, output_directory_wordcount,
    #       and have output columns name columns_name_hashtags and columns_name_wordcount.
    # TODO: insert your code here
    topTags.foreachRDD(lambda x:saveToStorage(x, output_directory_hashtags, columns_name_hashtags, "overwirte"))
    wordCount.foreachRDD(lambda x:saveToStorage(x, output_directory_wordcount, columns_name_wordcount, "append"))
    
    # start streaming process, wait for 600s and then stop.
    ssc.start()
    time.sleep(STREAMTIME)
    ssc.stop(stopSparkContext=False, stopGraceFully=True)

    # put the temp result in google storage to google BigQuery
    #saveToBigQuery(sc, output_dataset, output_table_hashtags, output_directory_hashtags)
    #saveToBigQuery(sc, output_dataset, output_table_wordcount, output_directory_wordcount)
# Out:
# -------------------------------------------
# Time: 2021-10-20 17:53:30
# -------------------------------------------
# ('#kakaakaonhotstar', 1)
# ('#onlymurdersinthebuilding', 1)
# ('#codmobile', 1)
# ('#cnft', 1)
# ('#cnfts', 1)
# ('#cardano', 1)
# ('#nft', 1)
# ('#nfts', 1)
# ('#barcadynamort', 1)
# ('#20oct', 1)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:53:35
# -------------------------------------------
# ('#machinelearning', 3)
# ('#codmobile', 2)
# ('#nft', 2)
# ('#antiindiasuperman', 2)
# ('#forex', 2)
# ('#ai', 2)
# ('#enhypen', 2)
# ('#billa', 2)
# ('#kakaakaonhotstar', 1)
# ('#onlymurdersinthebuilding', 1)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:53:40
# -------------------------------------------
# ('#machinelearning', 4)
# ('#enhypen', 3)
# ('#squidgames', 3)
# ('#codmobile', 2)
# ('#nft', 2)
# ('#antiindiasuperman', 2)
# ('#forex', 2)
# ('#ai', 2)
# ('#billa', 2)
# ('#kakaakaonhotstar', 1)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:53:45
# -------------------------------------------
# ('#machinelearning', 4)
# ('#squidgames', 4)
# ('#enhypen', 3)
# ('#codmobile', 2)
# ('#nft', 2)
# ('#antiindiasuperman', 2)
# ('#forex', 2)
# ('#ai', 2)
# ('#billa', 2)
# ('#kakaakaonhotstar', 1)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:53:50
# -------------------------------------------
# ('#machinelearning', 6)
# ('#ai', 4)
# ('#squidgames', 4)
# ('#datascience', 3)
# ('#enhypen', 3)
# ('#matrixprotocol', 3)
# ('#codmobile', 2)
# ('#nft', 2)
# ('#analytics', 2)
# ('#antiindiasuperman', 2)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:53:55
# -------------------------------------------
# ('#machinelearning', 6)
# ('#ai', 5)
# ('#squidgames', 5)
# ('#antiindiasuperman', 4)
# ('#matrixprotocol', 4)
# ('#datascience', 3)
# ('#enhypen', 3)
# ('#codmobile', 2)
# ('#nft', 2)
# ('#analytics', 2)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:00
# -------------------------------------------
# ('#ai', 10)
# ('#machinelearning', 7)
# ('#squidgames', 6)
# ('#antiindiasuperman', 5)
# ('#datascience', 5)
# ('#matrixprotocol', 4)
# ('#analytics', 3)
# ('#takeabreak', 3)
# ('#programming', 3)
# ('#devcommunity', 3)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:05
# -------------------------------------------
# ('#ai', 12)
# ('#machinelearning', 7)
# ('#squidgames', 7)
# ('#datascience', 6)
# ('#antiindiasuperman', 5)
# ('#analytics', 4)
# ('#programming', 4)
# ('#devcommunity', 4)
# ('#programmer', 4)
# ('#codenewbies', 4)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:10
# -------------------------------------------
# ('#ai', 14)
# ('#squidgames', 8)
# ('#machinelearning', 7)
# ('#datascience', 6)
# ('#antiindiasuperman', 5)
# ('#matrixprotocol', 5)
# ('#analytics', 4)
# ('#programming', 4)
# ('#devcommunity', 4)
# ('#programmer', 4)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:15
# -------------------------------------------
# ('#ai', 18)
# ('#machinelearning', 9)
# ('#squidgames', 8)
# ('#datascience', 7)
# ('#antiindiasuperman', 6)
# ('#matrixprotocol', 6)
# ('#bigdata', 4)
# ('#analytics', 4)
# ('#programming', 4)
# ('#devcommunity', 4)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:20
# -------------------------------------------
# ('#ai', 19)
# ('#machinelearning', 9)
# ('#squidgames', 9)
# ('#datascience', 8)
# ('#antiindiasuperman', 7)
# ('#matrixprotocol', 7)
# ('#bigdata', 5)
# ('#analytics', 5)
# ('#iot', 5)
# ('#ajithkumar', 4)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:25
# -------------------------------------------
# ('#ai', 19)
# ('#squidgames', 11)
# ('#machinelearning', 9)
# ('#datascience', 9)
# ('#matrixprotocol', 8)
# ('#antiindiasuperman', 7)
# ('#bigdata', 5)
# ('#analytics', 5)
# ('#iot', 5)
# ('#ajithkumar', 4)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:25
# -------------------------------------------
# ('ai', 140)
# ('I', 64)
# ('you', 29)
# ('are', 14)
#
# -------------------------------------------
# Time: 2021-10-20 17:54:30
# -------------------------------------------
# ('#ai', 20)
# ('#squidgames', 11)
# ('#machinelearning', 10)
# ('#datascience', 9)
# ('#matrixprotocol', 9)
# ('#antiindiasuperman', 7)
# ('#bigdata', 6)
# ('#analytics', 6)
# ('#iot', 5)
# ('#ajithkumar', 4)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:35
# -------------------------------------------
# ('#ai', 20)
# ('#squidgames', 12)
# ('#machinelearning', 11)
# ('#datascience', 10)
# ('#matrixprotocol', 10)
# ('#antiindiasuperman', 8)
# ('#bigdata', 6)
# ('#analytics', 6)
# ('#ajithkumar', 5)
# ('#iot', 5)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:40
# -------------------------------------------
# ('#ai', 22)
# ('#machinelearning', 12)
# ('#squidgames', 12)
# ('#matrixprotocol', 11)
# ('#datascience', 10)
# ('#antiindiasuperman', 8)
# ('#bigdata', 7)
# ('#iot', 7)
# ('#analytics', 6)
# ('#ajithkumar', 6)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:45
# -------------------------------------------
# ('#ai', 22)
# ('#machinelearning', 12)
# ('#matrixprotocol', 12)
# ('#squidgames', 12)
# ('#datascience', 10)
# ('#antiindiasuperman', 9)
# ('#bigdata', 7)
# ('#iot', 7)
# ('#nft', 6)
# ('#analytics', 6)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:50
# -------------------------------------------
# ('#ai', 22)
# ('#machinelearning', 13)
# ('#squidgames', 13)
# ('#antiindiasuperman', 12)
# ('#matrixprotocol', 12)
# ('#datascience', 11)
# ('#bigdata', 7)
# ('#iot', 7)
# ('#nft', 6)
# ('#analytics', 6)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:54:55
# -------------------------------------------
# ('#ai', 22)
# ('#machinelearning', 14)
# ('#squidgames', 14)
# ('#matrixprotocol', 13)
# ('#antiindiasuperman', 12)
# ('#datascience', 11)
# ('#bigdata', 7)
# ('#ajithkumar', 7)
# ('#iot', 7)
# ('#nft', 6)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:55:00
# -------------------------------------------
# ('#ai', 22)
# ('#squidgames', 15)
# ('#machinelearning', 14)
# ('#matrixprotocol', 14)
# ('#antiindiasuperman', 13)
# ('#datascience', 11)
# ('#bigdata', 7)
# ('#ajithkumar', 7)
# ('#iot', 7)
# ('#balajimurugadossrt', 7)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:55:05
# -------------------------------------------
# ('#ai', 25)
# ('#machinelearning', 15)
# ('#matrixprotocol', 15)
# ('#squidgames', 15)
# ('#antiindiasuperman', 13)
# ('#datascience', 12)
# ('#bigdata', 8)
# ('#iot', 8)
# ('#balajimurugadossrt', 8)
# ('#nft', 7)
# ...
#
# -------------------------------------------
# Time: 2021-10-20 17:55:10
# -------------------------------------------
# ('#ai', 26)
# ('#matrixprotocol', 16)
# ('#squidgames', 16)
# ('#machinelearning', 15)
# ('#antiindiasuperman', 14)
# ('#datascience', 12)
# ('#balajimurugadossrt', 10)
# ('#bigdata', 8)
# ('#iot', 8)
# ('#nft', 7)
# ...
